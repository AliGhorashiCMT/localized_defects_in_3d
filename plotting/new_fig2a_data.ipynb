# %%
import h5py 
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# %%
file_dir = "./data/"
filename = "data-sachin-23-3-26.dat"
data = np.loadtxt(file_dir + filename, skiprows=1, delimiter=',', usecols=range(1, 326));

# %%
plt.plot(data[:, 5:], color="black", linestyle="dashed");
plt.ylim(0.33, 0.36)
plt.xlim(0, 12)
plt.savefig("fig2a-revised.pdf")
