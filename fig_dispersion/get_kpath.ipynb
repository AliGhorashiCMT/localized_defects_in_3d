# %%
using Crystalline
using Brillouin

# %%
sgnum = 208
Rs = directbasis(sgnum)
kp = irrfbz_path(sgnum, Rs)
# Out:
# KPath{3} (4 points, 2 paths, 8 points in paths):
#  points: :R => [0.5, 0.5, 0.5]
#          :M => [0.5, 0.5, 0.0]
#          :Γ => [0.0, 0.0, 0.0]
#          :X => [0.0, 0.5, 0.0]
#   paths: [:Γ, :X, :M, :Γ, :R, :X]
#          [:R, :M]
#   basis: [6.283185, -0.0, -0.0]
#          [0.0, 6.283185, -0.0]
#          [0.0, 0.0, 6.283185]
